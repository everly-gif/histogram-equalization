# %% [markdown]
# ## Importing Libraries

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load Image

# %%
path = r"c://Users/hanis/downloads/A1-firt-image.tif" #image 1
img = cv.imread(path,0)

# %%
cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## View Original Image Histogram

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Histogram Equalization

# %%
equ = cv.equalizeHist(img)

# %%
cv.imshow('equ.png',equ)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
hist,bins = np.histogram(equ.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Load Image 2

# %%
path = r"c://Users/hanis/downloads/A1_second image.tif" #image 2
img = cv.imread(path,0)

# %%
cv.imshow('image',img)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ## View Original Image Histogram

# %%
hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Histogram Equalization

# %%
equ = cv.equalizeHist(img)

# %%
cv.imshow('equ.png',equ)
cv.waitKey(0)
cv.destroyAllWindows()

# %%
hist,bins = np.histogram(equ.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(equ.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %% [markdown]
# ## Comments on the output images

# %% [markdown]
# Unlike the original histogram, the pixel intensity values now range from 0 to 255 on the X-axis.
# In a way, the original histogram has been stretched to the far ends.
# The cummilative distribution function (CDF) line is now linear as opposed to the original curved line.
# The image contrast has been improved significantly using the histogram equalization technique.
# ![equalization_results.png](attachment:equalization_results.png)
